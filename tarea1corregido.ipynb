# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score

# %%
copier_df = pd.DataFrame({
    "Representante": [
        "Tom Keller", "Jeff Hall", "Brian Virost",
        "Greg Fish", "Susan Welch", "Nancy Drew",
        "Paul Smith", "Laura Green", "Mike Adams", "Sara Lee"
    ],
    "llamadas": [20, 40, 20, 30, 10, 25, 35, 15, 45, 28],
    "ventas":   [30, 60, 40, 60, 30, 45, 70, 35, 80, 50]
})

copier_df
# Out:
#   Representante  llamadas  ventas
# 0    Tom Keller        20      30
# 1     Jeff Hall        40      60
# 2  Brian Virost        20      40
# 3     Greg Fish        30      60
# 4   Susan Welch        10      30
# 5    Nancy Drew        25      45
# 6    Paul Smith        35      70
# 7   Laura Green        15      35
# 8    Mike Adams        45      80
# 9      Sara Lee        28      50

# %%
data.shape
# Out:
# (10, 3)

# %%
X_calls = copier_df[["llamadas"]].values
y_sales = copier_df["ventas"].values

modelo_copier = LinearRegression()
modelo_copier.fit(X_calls, y_sales)
# Out:
# LinearRegression()

# %%
predicciones = modelo_copier.predict(X_calls)

print("Pendiente:", modelo_copier.coef_[0])
print("Intercepto:", modelo_copier.intercept_)
print("MSE:", mean_squared_error(y_sales, predicciones))
print("R2:", r2_score(y_sales, predicciones))
# Out:
# Pendiente: 1.4524328249818441
# Intercepto: 11.074800290486579
# MSE: 32.610748002904884
# R2: 0.8769405735739438

# %%
prueba_llamadas = [[18]]
resultado = modelo_copier.predict(prueba_llamadas)

print(
    "Ventas estimadas para",
    prueba_llamadas[0][0],
    "llamadas:",
    round(resultado[0], 2)
)
# Out:
# Ventas estimadas para 18 llamadas: 37.22

# %%
plt.figure(figsize=(8,5))

plt.scatter(
    X_calls.flatten(),
    y_sales,
    color='steelblue',
    s=80,
    label='Datos reales'
)

plt.plot(
    X_calls.flatten(),
    modelo_copier.predict(X_calls),
    color='black',
    linewidth=3,
    label='Regresión lineal'
)

plt.xlabel("Número de llamadas")
plt.ylabel("Ventas")
plt.title("Copier Sales of America")
plt.legend()
plt.grid(alpha=0.4)
plt.show()
